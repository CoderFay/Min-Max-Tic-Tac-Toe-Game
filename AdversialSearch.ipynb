# %% [markdown]
# # <a id="pro"></a>
# # <center><h2 style="color:#f5f5f5;font-family: 'kawkab-bold';background-color:#808080;" >  Adversarial Search :Games </h2><br><br>

# %% [markdown]
# # $ Notebook$ $content$
#
# * 1-Purpose الهدف
#
# * 2-Introduction المقدمة
#
# * 3-An example problem مثال على المشكلة
#
# * 4-Formalization  of the problem الطابع الرسمي للعبة
#
# * 5-Game Strategy (additional information) استراتيجية اللعبة
#
# * 6-Artificial Intelligence Implementation (additional information) تنفيذ الذكاء الاصطناعي
#
# * 7-MiniMax algorithm خوارمينة mimmax
#   * 7.1 Explanation التفسير
#
#   * 7.2 Implementation التنفيذ
#
#   * 7.3 Testing  الاختبار
#
#   * 7.4 Performance measurement قياس الاداء
#
#   * 7.5 References and resources المصادر والمراجع
#
# * 8-Alpha-Beta Pruning خواوزمية alphabeta
#   * 8.1 Explanation التفسير
#
#   * 8.2 Implementation التنفيذ
#
#   * 8.3 Testing الاختبار
#
#   * 8.4 Performance measurement قياس الاداء
#
#   * 8.5 References and resources المصادر والمراجع
#
# * 9-Comparison of the two algorithms مقارنة بين الخوارمتين
#
# * 10-Conclusion الخلاصة

# %% [markdown]
# > # 1-Purpose:
#
#
# The purpose of this notebook is to help students who are interested in artificial intelligence (AI) especially in games which is a very important aspect of artificial intelligence. Games can be divided into several types based on the number of players and some other factors. This notebook is all about the competitive genre where two players play against each other. These types of games can be presented using artificial intelligence and solved using an algorithm called adversarial detection. One of these algorithms is called MinMax algorithm and it is a basis in playing such games and then the search process that can reduce the tree size due to the large size of the search tree in competitive games was improved by developing the alpha-beta pruning algorithm and it is considered a very important algorithm due to its ability to solve A competitive zero-sum game in less time and space.
#
#
# After completion, we will compare the performance measurement between the two algorithms
#
# Performance measurement is the process used to assess the efficiency and effectiveness of projects, programs and initiatives. It is a systematic approach to collecting, analyzing and evaluating how “on track” a project/program is to achieve its desired outcomes, goals and objectives.

# %% [markdown]
# # ١-الهدف
#
# الغرض من هذه المذكرة هو مساعدة الطلاب المهتمين بالذكاء الاصطناعي
# (AI) خاصة في الألعاب التي تعد جانبًا مهمًا للغاية من جوانب الذكاء الاصطناعي. يمكن تقسيم الألعاب إلى عدة أنواع بناءً على عدد اللاعبين وبعض العوامل الأخرى. تدور هذه المذكرة حول النوع التنافسي حيث يلعب لاعبان ضد بعضهما البعض. يمكن تقديم هذه الأنواع من الألعاب باستخدام الذكاء الاصطناعي وحلها باستخدام خوارزمية تسمى اكتشاف الخصومة “adversarial detection “. تسمى إحدى هذه الخوارزميات خوارزمية MinMax وهي أساس في لعب مثل هذه الألعاب ثم تم تحسين عملية البحث التي يمكن أن تقلل من حجم الشجرة بسبب الحجم الكبير لشجرة البحث في الألعاب التنافسية عن طريق تطوير خوارزمية تقليم ألفا بيتا “alpha-beta pruning “ وتعتبر خوارزمية مهمة للغاية نظرًا لقدرتها على حل لعبة تنافسية محصلتها صفر في وقت أقل .
#
# بعد الانتهاء ، سنقارن قياس الأداء بين الخوارزميتين
#
# قياس الأداء: العملية المستخدمة لتقييم كفاءة وفعالية المشاريع والبرامج والمبادرات. إنه نهج منظم لجمع وتحليل وتقييم كيف "يسير المشروع / البرنامج على المسار الصحيح" لتحقيق النتائج والأهداف والغايات المرجوة.

# %% [markdown]
# > # 2-Introduction :
#
#
# **Adversarial search** is search when there is an "enemy" or "opponent" changing the state of the problem every step in a direction you do not want.
#
# Examples: Chess, business, trading, war,you change state, but then you don't control the next state,opponent will change the next state in a way unpredictable hostile to you ,you only get to change every alternate state.
#
# So, Searches in which two or more players with conflicting goals are trying to explore the same search space for the solution, are called adversarial searches, often known as Games.
#
#  Games are modeled as a Search problem and heuristic evaluation function, and these are the two main factors which help to model and solve games in AI.

# %% [markdown]
# # ٢-المقدمة
#
# البحث العدائي هو البحث عندما يكون هناك «عدو» أو «خصم» يغير حالة المشكلة في كل خطوة في اتجاه لا تريده.
#
# أمثلة: الشطرنج، الأعمال، التجارة، الحرب، أنت تغير الحالة، ولكن بعد ذلك لا تتحكم في الحالة التالية، سيغير الخصم الحالة التالية بطريقة لا يمكن التنبؤ بها معادية لك، يمكنك فقط تغيير كل حالة بشكل متناوب.
#
# لذا، فإن عمليات البحث التي يحاول فيها اثنان أو أكثر من اللاعبين ذوي الأهداف المتعاكسة استكشاف نفس مساحة البحث عن الحل، تسمى عمليات البحث العدائية، والتي تُعرف غالبًا باسم الألعاب.
#
# تم تصميم الألعاب على غرار مشكلة البحث ووظيفة التقييم الاستدلالي، وهذان هما العاملان الرئيسيان اللذان يساعدان في نموذج وحل الألعاب في الذكاء الاصطناعي.

# %% [markdown]
# > # 3-An example problem:
#
# Example: **Tic-Tac-Toe game tree: what is Tic-Tac-Toe game**
# Tic-Tac-Toe is one of the paper-and-pencil games.
# This game requires two players in 3x3 grid with Player 1 acts as “O” and Player 2 acts as “X”, or vice versa .
#
# The objective of this game is to take place of three connecting grids in a horizontal, vertical, or diagonal way/fork.
# This game was first introduced at ancient time, however there is no evidence who invented it and which year. Some people think this game was invented at Ancient Egypt, and then Roman Empire called this game “Terni Lapili”.
#
# The grid drawing for the game had been found chalked all over the ancient city’s ruins.
# Terni Lapili was resurfaced in England with the name “Nought and Crosses” in 1864. This resurfaced version is the modern of Tic-Tac-Toe game that people know until this present day.
#
# In 1952, Alexander S. Douglas for the EDSAC computer at University of Cambridge developed a computerized Tic-Tac-Toe game called “OXO”. This was the first video game of Tic-Tac-Toe and it has AI inside, therefore human could play against the computer opponent.

# %% [markdown]
# # ٣-مثال على المشكلة
#
# مثال: شجرة لعبة Tic-Tac-Toe: ما هي لعبة Tic-Tac-Toe هي إحدى ألعاب الورق والقلم الرصاص. تتطلب هذه اللعبة لاعبين في شبكة 3x3 حيث يعمل اللاعب 1 كـ «O» ويعمل اللاعب 2 كـ «X» أو العكس.
#
# الهدف من هذه اللعبة هو إجراء ثلاث شبكات متصلة بطريقة أفقية أو رأسية أو قطرية.
# تم تقديم هذه اللعبة لأول مرة في الوقت القديم، ولكن لا يوجد دليل على من اخترعها وفي أي عام. يعتقد بعض الناس أن هذه اللعبة تم اختراعها في مصر القديمة، ثم أطلقت الإمبراطورية الرومانية على هذه اللعبة اسم «تيرني لابيلي».
#
# تم العثور على رسم الشبكة للعبة بالطباشير في جميع أنحاء أنقاض المدينة القديمة.
# عاد تيرني لابيلي إلى الظهور في إنجلترا باسم «Nought and Crosses» في عام 1864. هذه النسخة المعاد ظهورها هي لعبة Tic-Tac-Toe الحديثة التي يعرفها الناس حتى يومنا هذا.
#
# في عام 1952، طور ألكسندر إس دوغلاس لحاسوب EDSAC في جامعة كامبريدج لعبة Tic-Tac-Toe محوسبة تسمى «OXO». كانت هذه أول لعبة فيديو لـ Tic-Tac-Toe ولديها ذكاء اصطناعي بالداخل، وبالتالي يمكن للإنسان أن يلعب ضد خصم الكمبيوتر.

# %% [markdown]
# > #  4-Formalization  of the problem :
#
# A game can be defined as a type of search in AI which can be formalized of the following elements, we will use adversarial search in games and search to find the best moves to ensure victory. A game tree is a tree where nodes of the tree are the game states and Edges of the tree are the moves by players.
#
# Game tree involves initial state , state space, goal state, Evaluation function, and result Function
#
#
# * Initial state:
# It specifies how the game is set up at the start->Every tic-tac-toe game starts with an empty 3x3 matrix.
# * Intermediate State:
# Any arrangement of a 3x3 matrix obtained after applying valid rules on the current state.
# * State Space representation of Tic-Tac-Toe:
# Each state is denoted by the positions occupied by the letters of the two players in a 3x3 matrix and other empty places.
# Rules:  The players will get turns one after the other; they can mark their letters on the empty cell.
# * Goal state:
# The goal state is a board state having three Xs or Os in
# a row, column, or diagonal.
#
# * Player(s):
# It specifies which player has moved in the state space.
#
# * Action(s):
# It returns the set of legal moves in state space.
#
# * Result(s, a):
# It is the transition model, which specifies the result of moves in the state space.
#
# * Terminal-Test(s):
# Terminal test is true if the game is over, else it is false at any case. The state where the game ends is called terminal states.
#
# * Evaluation function :
# Is used to evaluate the "goodness" of a configuration of the game, also called the static evaluation function estimates board quality in leading to a win for one player.
# as we say that we will use Tic-Tac-Toe as an example, the evalution function will be :
# >+1 for computer ('O'), -1 for human ('X'), 0 for Tie
#
# * Utility(s, p):
# A utility function gives the final numeric value for a game that ends in terminal states s for player p.  It is also called payoff function. For Chess, the outcomes are a win, loss, or draw and its payoff values are +1, 0, ½. And for tic-tac-toe, utility values are +1, -1, and 0.

# %% [markdown]
# # ٤-الطابع الرسمي للمشكلة
#
#
# يمكن تعريف اللعبة على أنها نوع من البحث في الذكاء الاصطناعي يمكن إضافة الطابع الرسمي على العناصر التالية، وسنستخدم البحث العدائي في الألعاب والبحث للعثور على أفضل الحركات لضمان النصر. شجرة اللعبة هي شجرة تكون فيها عقد الشجرة هي حالات اللعبة وحواف الشجرة هي حركات اللاعبين.
#
# تتضمن شجرة اللعبة الحالة الأولية، ومساحة الحالة، وحالة الهدف، ووظيفة التقييم، ووظيفة النتيجة
#
#
# * الحالة الأولية:
# يحدد كيفية إعداد اللعبة في البداية -> كل لعبة اكس او تبدأ٣ × ٣  بمصفوفة فارغة
# * الحالة المتوسطة:
# أي ترتيب لمصفوفة٣ ×  ٣ يتم الحصول عليه بعد تطبيق قواعد صحيحة على الحالة الحالية.
# * تمثيل حالة المساحة لـ Tic-Tac-Toe:
# يشار إلى كل حالة بالمراكز التي تشغلها أحرف اللاعبين في مصفوفة 3x3 وأماكن فارغة أخرى.
# القواعد: سيحصل اللاعبون على ادوار واحدة تلو الأخرى ؛ يمكنهم وضع علامة على حروفهم على الاماكن الفارغة.
# * حالة الهدف:
# حالة الهدف هي حالة لوحة بها ثلاثة Xs أو Os في
# صف أو عمود أو قطري.
#
# * اللاعب (اللاعبين):
# يحدد اللاعب الذي تحرك في مساحة اللعبة.
#
# * الإجراء (الإجراءات):
# يعيد مجموعة التحركات القانونية في مساحة اللعبة.
#
# * النتيجة (النتائج، أ):
# إنه نموذج الانتقال، الذي يحدد نتيجة التحركات في مساحة اللعبة.
#
# * اختبار (اختبارات) النهاية:
# الاختبار النهائي صحيح إذا انتهت اللعبة، وإلا فهو خاطئ على أي حال. الحالة التي تنتهي فيها اللعبة تسمى الحالات الاخيره.
#
# * وظيفة التقييم:
# يستخدم لتقييم «جودة» تكوين اللعبة، ويسمى أيضًا وظيفة التقييم الثابت التي تقدر جودة اللوحة في مما يؤدي إلى فوز لاعب واحد.
# كما نقول أننا سنستخدم Tic-Tac-Toe كمثال، فإن وظيفة التقييم ستكون:
#
#    * + 1 للكمبيوتر ('O')، -1 للإنسان ('X')، 0 للتعادل
# * الخدمات (s, p):
# دالة الخدمات تعطي القيمة الرقمية النهائية للعبة التي تنتهي في الحالات الطرفية s للاعب p. بالنسبة للشطرنج، فإن النتائج هي الفوز أو الخسارة أو السحب وقيم مردودها + 1، 0، ½. وبالنسبة لـ tic-tac-toe، فإن قيم المنفعة هي + 1 و -1 و 0.

# %% [markdown]
# > # 5-Game Strategy (additional information):
#
# Tic-Tac-Toe game has many strategies that can be used. The main point of the strategy is the players have to block the opponent fork, either horizontally, vertically, or diagonally, while the players have to find their own fork to win.
# In combinatorial study, suppose “X” moves first, then the game is won as follows:
#
# •	91 distinct positions are won by X.
#
# •	44 distinct position are won by O.
#
# •	3 distinct positions are draw.
#
#  ![image.png](attachment:e7ecf1fa-79ed-4e12-a7c9-c42bacf20c4d.png)!

# %% [markdown]
# # ٥-استراتيجية اللعبة(معلومات اضافيه )
#
# تحتوي لعبة Tic-Tac-Toe على العديد من الاستراتيجيات التي يمكن استخدامها. النقطة الرئيسية في الإستراتيجية هي أنه يتعين على اللاعبين صد تفرع الخصم، إما أفقيًا أو عموديًا أو قطريًا، بينما يتعين على اللاعبين العثور على تفرع خاصة بهم للفوز.
# في الدراسة التوافقية، افترض أن «X» يتحرك أولاً، ثم يتم الفوز باللعبة على النحو التالي:
#
# •	91 مركزًا متميزًا فازت بها X.
#
# •	44 المركز المتميز فاز به O .
#
# •    3 مراكز متميزة تعني تعادل .

# %% [markdown]
# > # 6-Artificial Intelligence Implementation (additional information):
#
# Artificial Intelligence (AI) can be used for this game in order to play only single player, in other words human against computer. There are many samples of this game with AI on the internet, and each sample has its own algorithm for AI and it depends on the developer, which kind of algorithm will be used. One of AI algorithms that can be used for Tic-Tac-Toe is Minimax algorithm, this algorithm is a reliable algorithm for Tic-Tac-Toe game. By using this strategy, computer will avoid the loser condition against human.

# %% [markdown]
# # ٦-تنفيذ الذكاء الاصطناعي(معلومات اضافية)
#
#
# يمكن استخدام الذكاء الاصطناعي (AI) لهذه اللعبة من أجل لعب لاعب واحد فقط، بمعنى آخر الإنسان ضد الكمبيوتر. هناك العديد من عينات هذه اللعبة مع الذكاء الاصطناعي على الإنترنت، ولكل عينة خوارزمية خاصة بها للذكاء الاصطناعي وتعتمد على المطور، أي نوع من الخوارزمية سيتم استخدامه. إحدى خوارزميات الذكاء الاصطناعي التي يمكن استخدامها في Tic-Tac-Toe هي خوارزمية Minimax، هذه الخوارزمية هي خوارزمية موثوقة للعبة Tic-Tac-Toe. باستخدام هذه الاستراتيجية، سيتجنب الكمبيوتر حالة الخاسر ضد الإنسان.

# %% [markdown]
# ![image.png](attachment:f55b2574-03c6-42f1-bf42-43a3dfa69475.png)

# %% [markdown]
# > # 7-MiniMax algorithm:
# ### 7.1 $ Explanation:$
# The MiniMax algorithm is a recursive algorithm used in decision-making and game theory. It delivers an optimal move for the player, considering that the competitor is also playing optimally. This algorithm is widely used for game playing in Artificial Intelligence, such as chess, tic-tac-toe, and myriad double players games.
#
# In this algorithm, two players play the game; one is called ‘MAX’, and the other is ‘MIN.’ The goal of players is to minimize the opponent’s benefit and maximize self-benefit. The MiniMax algorithm conducts a depth-first search to explore the complete game tree and then proceeds down to the leaf node of the tree, then backtracks the tree using recursive calls.
# To better understand, let us consider an example of tic-tac-toe, a two-player game in which each player plays turn by turn.
#
# * MiniMax Illustration using Tic-Tac-Toe game
#
# To begin with, we are considering two rivals, Zoro and Sanji, from the One Piece (a famous Japanese Manga series). They decided to play the tic-tac-toe to resolve an argument. Zoro starts the game by picking ‘X’ and Sanji picks ‘O’ and plays second. In this example, Zoro will try to get the maximum possible score, and Sanji will try to minimize the possible score of Zoro. Figure 1 shows the game tree after an intermediate stage

# %% [markdown]
#  #  خوارزمية MiniMax -٧
#
#
# ### ٧.١ تفسير :
#
#
# خوارزمية MiniMax هي خوارزمية تكرار تستخدم في صنع القرار ونظرية اللعبة. إنه يقدم الخطوة المثلى للاعب، مع الأخذ في الاعتبار أن المنافس يلعب أيضًا بشكل مثالي. تُستخدم هذه الخوارزمية على نطاق واسع للعب في الذكاء الاصطناعي، مثل الشطرنج وتيك تاك تو وعدد لا يحصى من ألعاب اللاعبين المزدوجين.
#
# في هذه الخوارزمية، يلعب لاعبان اللعبة ؛ أحدهما يسمى «MAX» والآخر هو «MIN». الهدف من اللاعبين هو تقليل فائدة الخصم وتعظيم الفوائد الذاتية. تجري خوارزمية MiniMax بحثًا عميقًا أولاً لاستكشاف شجرة اللعبة الكاملة ثم تنتقل إلى العقدة الورقية للشجرة، ثم تتراجع عن الشجرة باستخدام نداء التكرار .
# لفهم أفضل، دعونا نفكر في مثال على tic-tac-toe، وهي لعبة من لاعبين يلعب فيها كل لاعب بدوره.
#
# * توضيح MiniMax باستخدام لعبة Tic-Tac-Toe
#
# في البداية ، نحن نفكر في منافسين، زورو وسانجي، من One Piece (سلسلة مانغا يابانية شهيرة). قرروا لعب tic-tac-toe لحل الجدل. يبدأ Zoro اللعبة باختيار «X» ويختار Sanji «O» ويلعب في المركز الثاني. في هذا المثال، سيحاول Zoro الحصول على أقصى درجة ممكنة، وسيحاول Sanji تقليل النتيجة المحتملة لـ Zoro. يوضح الشكل 1 شجرة اللعبة بعد مرحلة متوسطة!

# %% [markdown]
# ![image.png](attachment:0d6a3035-f6f7-49cd-8e3b-75e2e3fd5f6a.png)

# %% [markdown]
# ### 7.2 $ Implementation:$

# %%
# We'll use the time module to measure the time of evaluating
# game tree in every move. It's a nice way to show the
# distinction between the basic Minimax and Minimax with
# alpha-beta pruning :)
# Since we'll be implementing this through a tic-tac-toe game,
# let's go through the building blocks.
# First, let's make a constructor and draw out the board:
import time
import datetime
class Game:
    def __init__(self):
        self.initialize_game()

    def initialize_game(self):
        self.current_state = [['.','.','.'],
                              ['.','.','.'],
                              ['.','.','.']]

        # Player X always plays first, اللاعب اكس دائما يلعب اولا
        self.player_turn = 'X'

    def draw_board(self):
        for i in range(0, 3):
            for j in range(0, 3):
                print('{}|'.format(self.current_state[i][j]), end=" ")
            print()
        print()

    # Determines if the made move is a legal move, تحدد اذا كانت هذه الحركة مسموحه
    def is_valid(self, px, py):
        if px < 0 or px > 2 or py < 0 or py > 2:
            return False
        elif self.current_state[px][py] != '.':
            return False
        else:
            return True

    # Checks if the game has ended and returns the winner in each case,   يتحقق مما اذا كانت اللعبة قد انتهت ويعيد الفائ في كل حاله
    def is_end(self):
        # Vertical win
        for i in range(0, 3):
            if (self.current_state[0][i] != '.' and
                    self.current_state[0][i] == self.current_state[1][i] and
                    self.current_state[1][i] == self.current_state[2][i]):
                return self.current_state[0][i]

        # Horizontal win
        for i in range(0, 3):
            if (self.current_state[i] == ['X', 'X', 'X']):
                return 'X'
            elif (self.current_state[i] == ['O', 'O', 'O']):
                return 'O'

        # Main diagonal win
        if (self.current_state[0][0] != '.' and
                self.current_state[0][0] == self.current_state[1][1] and
                self.current_state[0][0] == self.current_state[2][2]):
            return self.current_state[0][0]

        # Second diagonal win
        if (self.current_state[0][2] != '.' and
                self.current_state[0][2] == self.current_state[1][1] and
                self.current_state[0][2] == self.current_state[2][0]):
            return self.current_state[0][2]

        # Is whole board full?
        for i in range(0, 3):
            for j in range(0, 3):
                # There's an empty field, we continue the game
                if (self.current_state[i][j] == '.'):
                    return None

        # It's a tie!
        return '.'

    # Player 'O' is max, in this case AI,اللاعب او في هذه الحاله هو الاكبر وهو الكمبيوتر
    def max(self, count):

        # Possible values for maxv are:
        # -1 - loss
        # 0  - a tie
        # 1  - win

        # We're initially setting it to -2 as worse than the worst case:
        maxv = -2

        px = None
        py = None

        result = self.is_end()

        # If the game came to an end, the function needs to return
        # the evaluation function of the end. That can be:
        # -1 - loss
        # 0  - a tie
        # 1  - win
        if result == 'X':
            return (-1, 0, 0, count)
        elif result == 'O':
            return (1, 0, 0, count)
        elif result == '.':
            return (0, 0, 0, count)

        for i in range(0, 3):
            for j in range(0, 3):
                if self.current_state[i][j] == '.':
                    # On the empty field player 'O' makes a move and calls Min
                    # That's one branch of the game tree.
                    self.current_state[i][j] = 'O'
                    (m, min_i, min_j, count) = self.min(count)
                    # Fixing the maxv value if needed
                    if m > maxv:
                        maxv = m
                        px = i
                        py = j
                    # Setting back the field to empty
                    self.current_state[i][j] = '.'
        count = count + 1
        return (maxv, px, py, count)

    # Player 'X' is min, in this case human,اللاعب اكس هو الاصغر في هذه الحاله وهو يمثل الانسان
    def min(self, count):

# Possible values for minv are:
        # -1 - win
        # 0  - a tie
        # 1  - loss

        # We're initially setting it to 2 as worse than the worst case:,  نعرفه مبدئيا بقيمة ٢ كأسوأ الحالات
        minv = 2

        qx = None
        qy = None

        result = self.is_end()

        if result == 'X':
            return (-1, 0, 0, count)
        elif result == 'O':
            return (1, 0, 0, count)
        elif result == '.':
            return (0, 0, 0, count)

        for i in range(0, 3):
            for j in range(0, 3):
                if self.current_state[i][j] == '.':
                    self.current_state[i][j] = 'X'
                    (m, max_i, max_j, count) = self.max(count)
                    if m < minv:
                        minv = m
                        qx = i
                        qy = j
                    self.current_state[i][j] = '.'


        count = count + 1
        return (minv, qx, qy, count)

    def play(self):
        count = 0
        depth = 0
        print("=================================================")
        print("TIC-TAC-TOE using MINIMAX Algorithm")
        print("=================================================")
        print(time.ctime())

        print("X is You and O is Computer")
        print("You will always start,ready ?!, Let's start the game 😍!")
        print("Position on the board according to coordinates X, Y")
        # 1,1 =>> Row No. 1 Column No. 1,Don't forget the numbering starts at 0 .
        # So 1.1 will be the position in the middle of the board.
        #التربيب ف اللوحة يعتمد على احداثيات x , y ويبدا تترقيم الصفوف والاعمدة من الصفر.


        while True:
            self.draw_board()
            self.result = self.is_end()
            dt = datetime.datetime.now()

            # Printing the appropriate message if the game has ended
            if self.result != None:
                if self.result == 'X':
                    print('The winner is X!🥳')
                    print(time.ctime())
                elif self.result == 'O':
                    print('The winner is O!😟!')
                    print(time.ctime())
                elif self.result == '.':
                    print("It's a tie!😀")
                    print(time.ctime())

                print("The maximum Depth of tree is =>>", depth)
                print("The Size of tree is =>>", count)


                self.initialize_game()
                return

            # If it's player's turn
            if self.player_turn == 'X':

                while True:

                    start = time.time()
                    (m, qx, qy, count) = self.min(count)
                    end = time.time()
                    print('Evaluation time⏳: {}s'.format(round(end - start, 7)))
                    print('Recommended move: X = {}, Y = {}'.format(qx, qy))

                    px = int(input('Insert the X coordinate: '))
                    py = int(input('Insert the Y coordinate: '))


                    (qx, qy) = (px, py)

                    if self.is_valid(px, py):
                        self.current_state[px][py] = 'X'
                        self.player_turn = 'O'
                        depth = depth + 1
                        break
                    else:
                        print('The move is not valid! Try again.')

            # If it's AI's turn
            else:
                (m, px, py, count) = self.max(count)
                self.current_state[px][py] = 'O'
                self.player_turn = 'X'
                depth=depth+1

def main():
         g = Game()
         g.play()


if __name__ == "__main__":
        main()

# %% [markdown]
# * <font color= red > Commands we added to the original code :</font>
#
# 1-The Depth account has been added to the tree.
#
# 2-The tree size has been calculated.
#
# 3-Evaluation time for each stage, as well as a library. -->like:Evaluation time: 0.0008798s
#
# 4-Time Calculates the date and time it takes for the code to be executed. -->like: Thu Nov  3 22:00:38 2022
#
# 5-There are additional printed sentences to illustrate the gameplay that appear when running the code .like-->
#
# X is You and O is Computer
#
# You will always start,ready ?!, Let's start the game!
#
# Position on the board according to coordinates X, Y

# %% [markdown]
# * الأوامر التي أضفناها إلى الكود البرمجي الأصلي
#
# 1- تمت إضافة حساب العمق إلى الشجرة.
#
# 2- تم حساب حجم الشجرة.
#
# 3 - وقت التقييم لكل مرحلة .
#
# 4- يحسب الوقت التاريخ والوقت الذي يستغرقه تنفيذ الرمز.
#
# 5- هناك جمل مطبوعة إضافية لتوضيح طريقة اللعب التي تظهر عند تشغيل الكود .

# %% [markdown]
# ### 7.3 $ Testing:$

# %% [markdown]
# ![‏لقطة الشاشة ١٤٤٤-٠٤-١١ في ١٢.٣٢.٣٢ ص.png](attachment:36ed1a1d-5daf-466c-b6f4-90ebd8b95067.png)
# ![‏لقطة الشاشة ١٤٤٤-٠٤-١٠ في ٥.٣١.٢٤ م.png](attachment:22776e29-de79-4678-af6c-ae68f6f612db.png)
# ![‏لقطة الشاشة ١٤٤٤-٠٤-١٠ في ٥.٣١.٥٧ م.png](attachment:c96882a7-47a5-4859-b98f-4bf04d1cac0b.png)

# %% [markdown]
# ### 7.4 $ Performance Measurement:$
#
# * Time Complexity worst case ,اسوأ حاله =>>O(b^m)
# * Space Complexity=>>O(bm)

# %% [markdown]
# ### 7.5 $References$ $and$ $resources: $(المراجع والمصادر)
#
#
# >Artificial Intelligence | Mini-Max Algorithm - Javatpoint
#
# >Mini-max algorithm is a recursive or backtracking algorithm which is used in decision-making and game theory. It…
# (www.javatpoint.com)
#
# >code source(https://stackabuse.com/minimax-and-alpha-beta-pruning-in-python/)
#
# >Another source about the game
# (https://medium.com/analytics-vidhya/tic-tac-toe-ai-vs-user-1a2903621737)

# %% [markdown]
# > # 8-Alpha-Beta Pruning:
#
# ### 8.1 $Explanation:$
#
# We will now expand upon minimax to make it so that the computer does not have to look at the entire tree.
# Consider the gametree of Tic-Tac-Toe displayed in Figure 1
# The value of the game is 1 for a computer win, -1 for a human win, and 0 for a draw.
# Note that the obvious move would be for the computer to play in the left-most subtree where it would block the human from getting three in a row along the diagonal.
# However, ordinary minimax would still need to traverse the whole tree to be able to make that decision.
# It would first take the minimum of the children of B, which is 0, and then compare that to the minimum of C’s children, which is -1. It would then find the maximum of the value of B (0) to the value of C (-1).
# But wait! Since C’s left child is -1, and C looks for the minimum of it’s children, the value of C is guaranteed to be less than or equal to -1 regardless of the value of its right child.
# And because -1 is less than 0, C is guaranteed to be a worse move than B just because of C’s left child. So the computer does not even need to look at C’s other children. This is the basis of what is called alpha-beta pruning.
#
# Consider the following addition to the code in the minimax algorithm in Figure 2. In this algorithm, we introduce the new parameters alpha and beta:
# • Alpha is the maximum value that can be attained at the current level or above.
# • Betaistheminimumvaluethatcanbeattainedatthecurrentlevelorabove.
# The initial call to minimaxab will be minimaxab(board, player, −∞, ∞). With this algorithm, the for-loop is broken whenever beta is less than or equal to alpha, meaning that the computer does have to look at the remaining children.
#
# * Alpha: Best already explored option for player Max
#
# * Beta: Best already explored option for player Min
#
# now break down exactly how the algorithm works after the initial call with the Tic-Tac-Toe game tree in Figure 1:
#
# •	The traversal starts on node A, where it is the computer’s turn, so player is equal to 1. Minimaxab is then called on A’s first child, node B, where player is -1.
#
# •	Minimaxab is then called on E, the first child of node B. We call on E’s only child, which will return a 1. E then returns 1 and val = 1 at B.
#
# •	Now the computer finds min(val, best), so best = min(∞, 1) = 1.
#
# •	beta = min(beta, best) = min(∞, 1) = 1. Since alpha is still −∞, beta ̸≤
# alpha, and the for loop continues.
#
# •	The computer looks at the value of B’sright child,which is 0,then compares it to val, which is 1. Since 0 < 1, val = 0, and beta = 0. B is out of children, so minimaxab returns 0 to node B.
#
#
# •	At node A, player = 1, so best = max(val, best) = max(0,−∞) = 0. Then alpha = max(−∞, 0) = 0.
# •	Minimaxab is called on the left child of node C, with alpha = 0 and beta = ∞, and with player = -1. Since at C we are starting a new for-loop, best = ∞, then val = -1, best = min(val, best) = -1, and beta = min(∞, -1) = -1. Here beta ≤ alpha is true, so the code breaks the for-loop and moves to node D with the same alpha = 0.
# •	At D, best is still ∞. We call upon D’s left child, where val = -1, so best = min(best, val) = -1, and beta = min(best, val) = -1. Since alpha is still equal to 0, we find that beta ≤ alpha, so for loop is broken and D’s right child is ignored.
# •	Finally, A finds max(0, -1) = 0 and returns 0. A is out of children so we are done.
# In this algorithm, we were able to ignore C’s right child and D’s right child. This may seem like a relatively small feat, but with larger trees, being able to prune an entire subtree when near the top is a great accomplishment for the computer. Figure 5 shows the number of board positions the two algorithms look at for the function call at different tree depths. Actual code for the two algorithms will be located in the appendix. Note that pruning has a much greater impact the larger the tree is. One can expect that for games more complicated than Tic-Tac-Toe pruning will be even more crucial to be able to find the best move while conserving computing power.

# %% [markdown]
#  #  ٨-الفا بيتا
# ### تفسير٨.١:
#
# سنقوم الآن بالتوسع في الحد الأدنى حتى لا يضطر الكمبيوتر إلى النظر إلى الشجرة بأكملها.
# ضع في اعتبارك لعبة Tic-Tac-Toe المعروضة في الشكل 1
# قيمة اللعبة هي 1 للفوز بالكمبيوتر، و -1 للفوز البشري، و 0 للتعادل.
# لاحظ أن الخطوة الواضحة ستكون أن يلعب الكمبيوتر في الجزء الفرعي الأيسر حيث يمنع الإنسان من الحصول على ثلاثة على التوالي على طول القطر.
# ومع ذلك، لا يزال الحد الأدنى العادي بحاجة إلى اجتياز الشجرة بأكملها لتتمكن من اتخاذ هذا القرار.
# سيأخذ أولاً الحد الأدنى من أطفال B، وهو 0، ثم يقارن ذلك بالحد الأدنى لأطفال C، وهو -1. ثم يجد الحد الأقصى لقيمة B (0) إلى قيمة C (-1).
# لكن انتظر! نظرًا لأن الطفل الأيسر لـ C هو -1، ويبحث C عن الحد الأدنى من أطفاله، فمن المضمون أن تكون قيمة C أقل من -1 أو تساوي -1 بغض النظر عن قيمة طفله الأيمن.
# ولأن -1 أقل من 0، فإن C مضمون أن تكون حركته أسوأ من B فقط بسبب الطفل الأيسر لـ C. لذلك لا يحتاج الكمبيوتر حتى إلى النظر إلى أطفال C الآخرين. هذا هو أساس ما يسمى تقليص ألفا بيتا.
#
# ضع في اعتبارك الإضافة التالية للكود في خوارزمية الحد الأدنى في الشكل 2.
# في هذه الخوارزمية، نقدم المعرفات الجديدة ألفا وبيتا:
# • ألفا هي القيمة القصوى التي يمكن بلوغها عند المستوى الحالي أو أعلى.
# • بيتا هي القيمة الدنيا التي يمكن تحقيقها على المستوى الحالي أو أعلى.
# ستكون الدعوة الأولية إلى minimaxab هي minimaxab(لوح، لاعب، −∞، ∞). باستخدام هذه الخوارزمية، يتم كسر الحلقة عندما يكون بيتا أقل من أو يساوي ألفا، مما يعني أن الكمبيوتر يجب أن ينظر إلى الأطفال المتبقين.
#
# ألفا: أفضل خيار تم استكشافه بالفعل للاعب الأكبر
#
# بيتا: أفضل خيار تم استكشافه بالفعل للاعب الأصغر
#
# الآن سنرى بالضبط كيفية عمل الخوارزمية بعد النداء الأولي مع شجرة لعبة Tic-Tac-Toe في الشكل 1:
#
# •	يبدأ العبور على العقدة A، حيث يأتي دور الكمبيوتر، لذا فإن اللاعب يساوي 1. ثم يتم استدعاء Minimaxab على أول طفل A، العقدة B، حيث يكون اللاعب -1.
#
# •	ثم يتم استدعاء Minimaxab على E، الطفل الأول للعقدة B. ندعو الطفل الوحيد لـ E، والذي سيعيد 1. ثم E ترجع 1 و val = 1 في B.
#
# •	الآن يجد الكمبيوتر min (val، best)، لذا الأفضل  =  1 .
#
# •	بيتا = min(beta, best) = min(∞, 1) = 1 . بما أن ألفا لا تزال −∞، بيتا  ̸≤ ألفا، والحلقة تستمر.
#
# •	ينظر الكمبيوتر إلى قيمة B 'srightchild، وهي 0، ثم يقارنها بـ val، وهي 1. منذ 0 < 1، val = 0، و beta = 0. B خارج الأطفال، لذا فإن minimaxab يعود 0 إلى العقدة B.
#
#
# •	في العقدة A، اللاعب = 1، لذا الأفضل = max (val، best) = max (0,−∞) = 0. ثم ألفا = الحد الأقصى (−∞، 0) = 0.
# •	يُطلق على Minimaxab الطفل الأيسر من العقدة C، مع alpha = 0 و beta = ∞، ومع اللاعب = -1. بما أننا في C نبدأ حلقة جديدة، الأفضل = ∞، ثم val = -1، الأفضل = min (val، best) = -1، و beta = min (∞، -1) = -1. هنا بيتا ≤ ألفا صحيح، لذلك فإن الرمز يكسر الحلقة وينتقل إلى العقدة D مع نفس ألفا = 0.
# •	في D، الأفضل لا يزال ∞. ندعو الطفل الأيسر لـ D، حيث val = -1، لذا الأفضل = min (best , val) = -1، و beta = min (best, val) = -1. بما أن ألفا لا تزال تساوي 0، نجد أن بيتا ≤ ألفا، لذلك بالنسبة للحلقة يتم كسرها ويتم تجاهل الطفل الأيمن D.
#
# وأخيرا،
# A تجد الحد الأقصى (0، -1) = 0 ويرجع 0. A من الأطفال لذلك انتهينا.
# في هذه الخوارزمية، تمكنا من تجاهل طفل C الأيمن وطفل D الأيمن. قد يبدو هذا إنجازًا صغيرًا نسبيًا، ولكن مع وجود أشجار أكبر، فإن القدرة على تقليص مجموعة فرعية كاملة عندما تكون بالقرب من القمة يعد إنجازًا رائعًا للكمبيوتر. يوضح الشكل 5 عدد مواقع اللوحة التي تبحث فيها الخوارزميتان عن نداء الوظيفة في أعماق الأشجار المختلفة. سيتم وضع الكود الفعلي للخوارزميتين في التذييل. لاحظ أن التقليص له تأثير أكبر بكثير كلما كانت الشجرة أكبر. يمكن للمرء أن يتوقع أنه بالنسبة للألعاب الأكثر تعقيدًا من تقليص Tic-Tac-Toe سيكون أكثر أهمية حتى تتمكن من العثور على أفضل حركة مع الحفاظ على قوة الحوسبة.

# %% [markdown]
# Figure 1: An example Tic-Tac-Toe game tree. With the minimaxab algorithm, nodes H and J are pruned. While pruning just two nodes may seem like a small accomplishment, if a node is pruned higher up in the game tree it would be a much bigger feat.
#  ![image.png](attachment:8d02079a-f4c6-44ce-b66c-ad0229d9c3fd.png)

# %% [markdown]
# Figure 2: The full algorithm for minimaxab in pseudocode, with the differences from minimax highlighted in yellow. The additional parameters alpha and beta are used to help prune the game tree by breaking the for-loop.
#
#  ![image.png](attachment:8f1750f4-0722-4491-911e-585e43a3713e.png)

# %% [markdown]
# الشكل 2: الخوارزمية الكاملة لـ minimaxab في psuedocode، مع إبراز الاختلافات من minimax باللون الأصفر. يتم استخدام المعرفات الإضافية ألفا وبيتا للمساعدة في تقليص شجرة اللعبة عن طريق كسر حلقة التكرار.

# %% [markdown]
# ### 8.2 $Implementation:$

# %%
# We'll use the time module to measure the time of evaluating
# game tree in every move. It's a nice way to show the
# distinction between the basic Minimax and Minimax with
# alpha-beta pruning :)
import time
import datetime
# Since we'll be implementing this through a tic-tac-toe game,
# let's go through the building blocks.
# First, let's make a constructor and draw out the board:
class Game:
    def __init__(self):
        self.initialize_game()

    def initialize_game(self):
        self.current_state = [['.','.','.'],
                              ['.','.','.'],
                              ['.','.','.']]

        # Player X always plays first, اللاعب اكس دائما يبدأ
        self.player_turn = 'X'

    def draw_board(self):
        for i in range(0, 3):
            for j in range(0, 3):
                print('{}|'.format(self.current_state[i][j]), end=" ")
            print()
        print()

    # Determines if the made move is a legal move, تحدد ما اذا كانت الحركة مسموحة
    def is_valid(self, px, py):
        if px < 0 or px > 2 or py < 0 or py > 2:
            return False
        elif self.current_state[px][py] != '.':
            return False
        else:
            return True

    # Checks if the game has ended and returns the winner in each case, تتحقق هل انتهت اللعبة وتعيد الفائز فيه كل حاله
    def is_end(self):
        # Vertical win
        for i in range(0, 3):
            if (self.current_state[0][i] != '.' and
                    self.current_state[0][i] == self.current_state[1][i] and
                    self.current_state[1][i] == self.current_state[2][i]):
                return self.current_state[0][i]

        # Horizontal win
        for i in range(0, 3):
            if (self.current_state[i] == ['X', 'X', 'X']):
                return 'X'
            elif (self.current_state[i] == ['O', 'O', 'O']):
                return 'O'

        # Main diagonal win
        if (self.current_state[0][0] != '.' and
                self.current_state[0][0] == self.current_state[1][1] and
                self.current_state[0][0] == self.current_state[2][2]):
            return self.current_state[0][0]

        # Second diagonal win
        if (self.current_state[0][2] != '.' and
                self.current_state[0][2] == self.current_state[1][1] and
                self.current_state[0][2] == self.current_state[2][0]):
            return self.current_state[0][2]

        # Is whole board full?
        for i in range(0, 3):
            for j in range(0, 3):
                # There's an empty field, we continue the game
                if (self.current_state[i][j] == '.'):
                    return None

        # It's a tie!
        return '.'

    # Player 'O' is max, in this case AI, اللاعب او هو الاكبر في هذه الحاله وهو يمثل الكمبيوتر
    def max_alpha_beta(self, alpha, beta, count):
        maxv = -2
        px = None
        py = None

        result = self.is_end()

        if result == 'X':
            return (-1, 0, 0, count)
        elif result == 'O':
            return (1, 0, 0, count)
        elif result == '.':
            return (0, 0, 0, count)

        for i in range(0, 3):
            for j in range(0, 3):
                if self.current_state[i][j] == '.':
                    self.current_state[i][j] = 'O'
                    (m, min_i, in_j, count) = self.min_alpha_beta(alpha, beta, count)
                    if m > maxv:
                        maxv = m
                        px = i
                        py = j
                    self.current_state[i][j] = '.'

                    # Next two ifs in Max and Min are the only difference between regular algorithm and minimax
                    if maxv >= beta:
                        return (maxv, px, py, count)

                    if maxv > alpha:
                        alpha = maxv
        count = count + 1
        return (maxv, px, py, count)
    # Player 'X' is min, in this case human,اللاعب اكس هو الاصغر في هذه الحاله وهو يمثل الانسان
    def min_alpha_beta(self, alpha, beta, count):

        minv = 2

        qx = None
        qy = None

        result = self.is_end()

        if result == 'X':
            return (-1, 0, 0, count)
        elif result == 'O':
            return (1, 0, 0, count)
        elif result == '.':
            return (0, 0, 0, count)


        for i in range(0, 3):
            for j in range(0, 3):
                if self.current_state[i][j] == '.':
                    self.current_state[i][j] = 'X'
                    (m, max_i, max_j, count) = self.max_alpha_beta(alpha, beta, count)
                    if m < minv:
                        minv = m
                        qx = i
                        qy = j
                    self.current_state[i][j] = '.'

                    if minv <= alpha:
                        return (minv, qx, qy, count)

                    if minv < beta:
                        beta = minv
        count = count + 1
        return (minv, qx, qy, count)

    def play_alpha_beta(self):
        count = 0
        depth = 0
        print("=================================================")
        print(" TIC-TAC-TOE using MINIMAX with ALPHA-BETA Pruning Algorithm")
        print("=================================================")
        print(time.ctime())

        print("X is You and O is Computer")
        print("You will always start,ready ?!, Let's start the game 😍!")
        print("Position on the board according to coordinates X, Y")
        # 1,1 =>> Row No. 1 Column No. 1,Don't forget the numbering starts at 0 .
        # So 1.1 will be the position in the middle of the board.
        # التربيب ف اللوحة يعتمد على احداثيات x , y ويبدا تترقيم الصفوف والاعمدة من الصفر.

        while True:
            self.draw_board()
            self.result = self.is_end()
            dt = datetime.datetime.now()

            if self.result != None:
                if self.result == 'X':
                    print(' The winner is X!🥳')
                    print(time.ctime())
                elif self.result == 'O':
                    print('The winner is O!😟!')
                    print(time.ctime())
                elif self.result == '.':
                    print("It's a tie!😀")
                    print(time.ctime())

                print("The maximum Depth of tree is =>>", depth)
                print("The Size of tree is =>>", count)

                self.initialize_game()
                return

            if self.player_turn == 'X':

                while True:
                    start = time.time()
                    (m, qx, qy, count) = self.min_alpha_beta(-2, 2, count)
                    end = time.time()
                    print('Evaluation time⏳: {}s'.format(round(end - start, 7)))
                    print('Recommended move: X = {}, Y = {}'.format(qx, qy))

                    px = int(input('Insert the X coordinate: '))
                    py = int(input('Insert the Y coordinate: '))

                    qx = px
                    qy = py

                    if self.is_valid(px, py):
                        self.current_state[px][py] = 'X'
                        self.player_turn = 'O'
                        depth = depth + 1

                        break
                    else:
                        print('The move is not valid! Try again.')

            else:
                (m, px, py, count) = self.max_alpha_beta(-2, 2, count)
                self.current_state[px][py] = 'O'
                self.player_turn = 'X'
                depth = depth + 1


def main():
        g = Game()
        g.play_alpha_beta()
if __name__ == "__main__":
        main()
# Out:
# ...
#  TIC-TAC-TOE using MINIMAX with ALPHA-BETA Pruning Algorithm
# ...
# Tue Nov  8 12:12:02 2022
# X is You and O is Computer
# You will always start,ready ?!, Let's start the game 😍!
# Position on the board according to coordinates X, Y
# .| .| .|
# .| .| .|
# .| .| .|
#
# Evaluation time⏳: 0.1866751s
# Recommended move: X = 0, Y = 0

# %% [markdown]
# * <font color= red > Commands we added to the original code :</font>
#
# 1-The Depth account has been added to the tree.
#
# 2-The tree size has been calculated.
#
# 3-Evaluation time for each stage, as well as a library. -->Evaluation time: 0.0002012s
#
# 4-Time Calculates the date and time it takes for the code to be executed. -->like: Thu Nov  3 22:01:18 2022
#
# 5-There are additional printed sentences to illustrate the gameplay that appear when running the code .like-->
# X is You and O is Computer
#
# You will always start,ready ?!, Let's start the game!
#
# Position on the board according to coordinates X, Y

# %% [markdown]
# ### ٨.١ التنفيذ:
#
# الأوامر التي أضفناها إلى الكود البرمجي الأصلي
#
# 1- تمت إضافة حساب العمق إلى الشجرة.
#
# 2- تم حساب حجم الشجرة.
#
# 3 - وقت التقييم لكل مرحلة .
#
# 4- يحسب الوقت التاريخ والوقت الذي يستغرقه تنفيذ الرمز.
#
# 5- هناك جمل مطبوعة إضافية لتوضيح طريقة اللعب التي تظهر عند تشغيل الكود .

# %% [markdown]
# ### 8.3 $Testing:$

# %% [markdown]
# ![‏لقطة الشاشة ١٤٤٤-٠٤-١١ في ١٢.٣٠.٢٧ ص.png](attachment:f42ffb33-56d2-417d-845b-0af3b4e9f275.png)
# ![‏لقطة الشاشة ١٤٤٤-٠٤-١١ في ١٢.٣٠.٣٧ ص.png](attachment:a3df11d2-9877-4d22-986f-2b99c1380dae.png)
# ![‏لقطة الشاشة ١٤٤٤-٠٤-١١ في ٦.٥٤.١٨ م.png](attachment:a76e345d-8f8e-45f9-8086-acaca861114c.png)

# %% [markdown]
# ### 8.4 $ Performance$ $Measurement:$
#
# * Time Complexity on worst case,اسوأ حالة =>> no pruning like MinMax O(b^m), best case, افضل حالة=>> for perfect ordering O(b^m/2)
#
# * Guaranteed to compute same root value as Minimax
# يضمن ان يحسب قيمة الروت نفس مين ماكس
#
# * Space Complexity=>>O(bdm)

# %% [markdown]
# ###  8.5 $References$ $and$ $ resources :$(المراجع والمصادر)

# %% [markdown]
# >code source(https://stackabuse.com/minimax-and-alpha-beta-pruning-in-python/)
#
# >Alpha-Beta Pruning
# Carl Felstiner
# May 9, 2019
# (https://www.whitman.edu/documents/Academics/Mathematics/2019/Felstiner-Guichard.pdf)

# %% [markdown]
# > # 9-Comparison of the two algorithms:

# %% [markdown]
# # ٩-مقارنة الخوارزميتين

# %% [markdown]
#  $ in MinMax:$
#
# * nubmer of win for AI >> 7
#
# * number of loss for AI >> 0
#
# * number of tie->> 3
#
# * maximum depth for all 10 times >> 9
#
# * maximum size for all 10 times >> 335586
#
# * maximum time for all 10 times >> 30 second
#
# $ in AlphaBeta:$
#
# * number of win for AI >> 6
#
# * number of loss for AI >> 0
#
# * number of tie >> 4
#
# * maximum depth for all 10 times >> 9
#
# * maximum size for all 10 times >> 4253
#
# * maximum time for all 10 times >> 14 second
#
# ##### The size was 335586 and it became a 4253 which is a very big change !!
#
# ##### The time was 30s and it became a 14s which is a very big change !!

# %% [markdown]
# $ في MinMax: $
#
# * عدد مرات الفوز  AI >> 7
#
# * عدد الخسارة  AI >> 0
#
# * عدد التعادل AI >> 3
#
#
# * أقصى عمق لجميع المرات العشر >> 9
#
# * الحجم الأقصى لجميع المرات العشر >> 335285
#
# * أقصى وقت لجميع الأوقات العشر >> 30 ثانية
#
# $ في AlphaBeta: $
#
# * عدد مرات الفوز  AI >> 6
#
# * عدد الخسارة  AI >> 0
#
# * عدد التعادل AI >> 4
#
# * أقصى عمق لجميع المرات العشر >> 9
#
# * أقصى حجم لجميع 10 مرات >> 4253
#
# * أقصى وقت لجميع المرات العشر >> 14 ثانية
#
# ##### الحجم كان 335285 وأصبح 4253 وهو تغيير كبير جدًا !!
#
# ##### كان الوقت 30 ثانية وأصبح 14 ثانية وهو تغيير كبير جدًا !!

# %% [markdown]
# > # 10-Conclusion:

# %% [markdown]
# We’ve created the Utility and Evaluation Function that is used by Minimax algorithm. Note that using the minimax algorithm with pruning will significantly decrease the execution time of large complex games. Even though tic-tac-toe is a simple game, you can still notice the difference in the time the AI takes to make a move.

# %% [markdown]
# # ١٠-الخلاصة
#
# لقد أنشأنا وظيفة الأداة المساعدة والتقييم التي تستخدمها خوارزمية الحد الأدنى. لاحظ أن استخدام خوارزمية الحد الأدنى مع التقليم سيقلل بشكل كبير من وقت تنفيذ الألعاب المعقدة الكبيرة. على الرغم من أن لعبة أكس-اوهي لعبة بسيطة ، فلا يزال بإمكانك ملاحظة الفرق في الوقت الذي يستغرقة الذكاء الاصنطاعي في اتخاذ خطوة.
